# %%
import sys
import os
import torch

# %%
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# True
# NVIDIA A100 80GB PCIe MIG 1g.10gb

# %%
# import sys
# import os
# import torch
sys.argv = ['bert_main_wo_reg.py', 'plain', 'bert_plain_test_output.csv', '0.3', '5e-5']

from bert_main_wo_reg import main_final

main_final()
# Out:
# 04/16/2026 16:40:28 - INFO - bert_data -   ***** Running training *****
# 04/16/2026 16:40:28 - INFO - bert_data -     Num examples = 3312
# 04/16/2026 16:40:28 - INFO - bert_data -     Batch size = 16
# 04/16/2026 16:40:28 - INFO - bert_data -     Num steps = 4140
# 04/16/2026 16:40:29 - INFO - bert_data -   ***** Running evaluation *****
# 04/16/2026 16:40:29 - INFO - bert_data -     Num examples = 369
# 04/16/2026 16:40:29 - INFO - bert_data -     Batch size = 16
# ...
# Iteration: 100%|██████████| 207/207 [02:54<00:00,  1.19it/s]
# 04/16/2026 16:43:24 - INFO - bert_data -   Loss after epoc 0.39019811218199524
# 04/16/2026 16:43:24 - INFO - bert_data -   Eval after epoc 1
# /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages/sklearn/metrics/_ranking.py:1188: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# ...
