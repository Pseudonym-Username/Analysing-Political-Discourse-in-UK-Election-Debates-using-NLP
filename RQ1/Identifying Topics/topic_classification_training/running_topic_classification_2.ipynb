# %%
import shutil
shutil.make_archive('Dayanik_et_al_2022', 'zip', './Dayanik_et_al_2022/')

print("Archive created successfully!")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File /usr/lib/python3.9/zipfile.py:1783, in ZipFile.write(self, filename, arcname, compress_type, compresslevel)
#    1782 with open(filename, "rb") as src, self.open(zinfo, 'w') as dest:
# -> 1783     shutil.copyfileobj(src, dest, 1024*8)
#
# File /usr/lib/python3.9/shutil.py:208, in copyfileobj(fsrc, fdst, length)
#     207     break
# --> 208 fdst_write(buf)
#
# File /usr/lib/python3.9/zipfile.py:1140, in _ZipWriteFile.write(self, data)
#    1139     self._compress_size += len(data)
# -> 1140 self._fileobj.write(data)
#    1141 return nbytes
#
# OSError: [Errno 5] Input/output error
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# ...

# %%
# !du -ah . | sort -rh | head -n 10
# Out:
# 2.9G	./Dayanik_et_al_2022/code
# 2.9G	./Dayanik_et_al_2022
# 2.9G	.
# 834M	./Dayanik_et_al_2022/code/outputs
# 703M	./Dayanik_et_al_2022/code/2026_04_20_13-52_38_final.bin.final
# 703M	./Dayanik_et_al_2022/code/2026_04_20_13-52_38_final.bin
# 703M	./Dayanik_et_al_2022/code/2026_04_19_21-31_25_final.bin.final
# 417M	./Dayanik_et_al_2022/code/outputs/2026_04_16_16-40_26_final.bin.final
# 417M	./Dayanik_et_al_2022/code/outputs/2026_04_16_16-40_26_final.bin
# 1.2M	./Dayanik_et_al_2022/data

# %%
# !rm -rf /home2/pwfb75/.cache/huggingface/hub/models--unsloth--Mistral-Nemo-Instruct-2407-bnb-4bit
# !rm -rf /home2/pwfb75/.cache/huggingface/hub/models--openai--clip-vit-base-patch32


print("Cache cleared.")
# Out:
# Cache cleared.

# %%
import os
import sys
import torch
from contextlib import redirect_stdout

original_code_dir = os.path.abspath("./Dayanik_et_al_2022/code")

if original_code_dir not in sys.path:
    sys.path.append(original_code_dir)
os.chdir(original_code_dir)

# %%
# CRR Model
sys.argv = ['bert_main.py', 'plain', 'bert_crr_test_output.csv', '0.005', '-0.01', '0.4', '5e-5']  

from bert_main_wo_reg import main_final

with open('../../training_log.txt', 'w') as f:
    with redirect_stdout(f):
        main_final()

main_final()
# Out:
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/481 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Token indices sequence length is longer than the specified maximum sequence length for this model (584 > 512). Running this sequence through the model will result in indexing errors
# 04/19/2026 20:25:25 - INFO - bert_data -   ***** Running training *****
# 04/19/2026 20:25:25 - INFO - bert_data -     Num examples = 2869
# 04/19/2026 20:25:25 - INFO - bert_data -     Batch size = 16
# 04/19/2026 20:25:25 - INFO - bert_data -     Num steps = 3580
# 04/19/2026 20:25:25 - INFO - bert_data -   ***** Running evaluation *****
# 04/19/2026 20:25:25 - INFO - bert_data -     Num examples = 369
# 04/19/2026 20:25:25 - INFO - bert_data -     Batch size = 16
# model.safetensors:   0%|          | 0.00/499M [00:00<?, ?B/s]
# ...
