# %%
# !pip install sentence-transformers
# Out:
# Collecting sentence-transformers
#   Downloading sentence_transformers-5.1.2-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from sentence-transformers) (4.57.3)
# Requirement already satisfied: tqdm in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from sentence-transformers) (2.8.0)
# Requirement already satisfied: scikit-learn in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: scipy in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from sentence-transformers) (0.36.0)
# Requirement already satisfied: Pillow in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from sentence-transformers) (11.3.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: filelock in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (3.19.1)
# Requirement already satisfied: numpy>=1.17 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2026.1.15)
# Requirement already satisfied: requests in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2.32.5)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.22.2)
# Requirement already satisfied: safetensors>=0.4.3 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.7.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.10.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (1.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers) (3.2.1)
# Requirement already satisfied: jinja2 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers) (1.13.1.3)
# Requirement already satisfied: triton==3.4.0 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers) (3.4.0)
# Requirement already satisfied: setuptools>=40.8.0 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from triton==3.4.0->torch>=1.11.0->sentence-transformers) (80.10.2)
# Requirement already satisfied: importlib-metadata in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from triton==3.4.0->torch>=1.11.0->sentence-transformers) (8.7.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: zipp>=3.20 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from importlib-metadata->triton==3.4.0->torch>=1.11.0->sentence-transformers) (3.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (2026.1.4)
# Requirement already satisfied: joblib>=1.2.0 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from scikit-learn->sentence-transformers) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Downloading sentence_transformers-5.1.2-py3-none-any.whl (488 kB)
# Installing collected packages: sentence-transformers
# Successfully installed sentence-transformers-5.1.2
#
# [notice] A new release of pip is available: 20.0.2 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import torch
from transformers import BertModel, BertTokenizer
from sentence_transformers import SentenceTransformer, losses, InputExample
from torch.utils.data import DataLoader

# %%
class MLBERT(torch.nn.Module):
    def __init__(self, model_name, num_labels):
        super().__init__()
        self.bert = BertModel.from_pretrained(model_name)
        self.classifier = torch.nn.Linear(768, num_labels)
        self.sigmoid = torch.nn.Sigmoid()
        
    def forward(self, input_ids, attention_mask):
        outputs = self.bert(input_ids, attention_mask=attention_mask)        
        return self.sigmoid(self.classifier(outputs[1]))
