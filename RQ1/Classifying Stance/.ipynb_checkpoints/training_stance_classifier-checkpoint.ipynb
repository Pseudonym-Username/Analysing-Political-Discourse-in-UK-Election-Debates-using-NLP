# %%
# !pip install setfit datasets
# Out:
# Collecting setfit
#   Downloading setfit-1.1.3-py3-none-any.whl.metadata (12 kB)
# Collecting datasets
#   Downloading datasets-4.5.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: sentence-transformers>=3 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from sentence-transformers[train]>=3->setfit) (5.1.2)
# Requirement already satisfied: transformers>=4.41.0 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from setfit) (4.57.6)
# Collecting evaluate>=0.3.0 (from setfit)
#   Downloading evaluate-0.4.6-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: huggingface_hub>=0.24.0 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from setfit) (0.36.2)
# Requirement already satisfied: scikit-learn in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from setfit) (1.6.1)
# Requirement already satisfied: packaging in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from setfit) (26.1)
# Requirement already satisfied: filelock in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from datasets) (3.19.1)
# Requirement already satisfied: numpy>=1.17 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from datasets) (2.0.2)
# Collecting pyarrow>=21.0.0 (from datasets)
#   Downloading pyarrow-21.0.0-cp39-cp39-manylinux_2_28_x86_64.whl.metadata (3.3 kB)
# Collecting dill<0.4.1,>=0.3.0 (from datasets)
#   Downloading dill-0.4.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from datasets) (2.2.3)
# Requirement already satisfied: requests>=2.32.2 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from datasets) (2.32.5)
# Requirement already satisfied: httpx<1.0.0 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from datasets) (0.28.1)
# Requirement already satisfied: tqdm>=4.66.3 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from datasets) (4.67.3)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.6.0-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (13 kB)
# Collecting multiprocess<0.70.19 (from datasets)
#   Downloading multiprocess-0.70.18-py39-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: fsspec<=2025.10.0,>=2023.1.0 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (2025.10.0)
# Requirement already satisfied: pyyaml>=5.1 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from datasets) (6.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (3.13.3)
# Requirement already satisfied: anyio in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from httpx<1.0.0->datasets) (4.12.1)
# Requirement already satisfied: certifi in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from httpx<1.0.0->datasets) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from httpx<1.0.0->datasets) (1.0.9)
# Requirement already satisfied: idna in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from httpx<1.0.0->datasets) (3.11)
# Requirement already satisfied: h11>=0.16 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.16.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from huggingface_hub>=0.24.0->setfit) (1.4.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from huggingface_hub>=0.24.0->setfit) (4.15.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (5.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.22.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from requests>=2.32.2->datasets) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from requests>=2.32.2->datasets) (2.6.3)
# Requirement already satisfied: torch>=1.11.0 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from sentence-transformers>=3->sentence-transformers[train]>=3->setfit) (2.8.0)
# Requirement already satisfied: scipy in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from sentence-transformers>=3->sentence-transformers[train]>=3->setfit) (1.13.1)
# Requirement already satisfied: Pillow in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from sentence-transformers>=3->sentence-transformers[train]>=3->setfit) (11.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from transformers>=4.41.0->setfit) (2026.1.15)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from transformers>=4.41.0->setfit) (0.22.2)
# Requirement already satisfied: safetensors>=0.4.3 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from transformers>=4.41.0->setfit) (0.7.0)
# Requirement already satisfied: accelerate>=0.20.3 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from sentence-transformers[train]>=3->setfit) (1.10.1)
# Requirement already satisfied: psutil in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from accelerate>=0.20.3->sentence-transformers[train]>=3->setfit) (7.2.1)
# Requirement already satisfied: sympy>=1.13.3 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers>=3->sentence-transformers[train]>=3->setfit) (1.14.0)
# Requirement already satisfied: networkx in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers>=3->sentence-transformers[train]>=3->setfit) (3.2.1)
# Requirement already satisfied: jinja2 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers>=3->sentence-transformers[train]>=3->setfit) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers>=3->sentence-transformers[train]>=3->setfit) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers>=3->sentence-transformers[train]>=3->setfit) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers>=3->sentence-transformers[train]>=3->setfit) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers>=3->sentence-transformers[train]>=3->setfit) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers>=3->sentence-transformers[train]>=3->setfit) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers>=3->sentence-transformers[train]>=3->setfit) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers>=3->sentence-transformers[train]>=3->setfit) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers>=3->sentence-transformers[train]>=3->setfit) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers>=3->sentence-transformers[train]>=3->setfit) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers>=3->sentence-transformers[train]>=3->setfit) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers>=3->sentence-transformers[train]>=3->setfit) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers>=3->sentence-transformers[train]>=3->setfit) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers>=3->sentence-transformers[train]>=3->setfit) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers>=3->sentence-transformers[train]>=3->setfit) (1.13.1.3)
# Requirement already satisfied: triton==3.4.0 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers>=3->sentence-transformers[train]>=3->setfit) (3.4.0)
# Requirement already satisfied: setuptools>=40.8.0 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from triton==3.4.0->torch>=1.11.0->sentence-transformers>=3->sentence-transformers[train]>=3->setfit) (80.10.2)
# Requirement already satisfied: importlib-metadata in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from triton==3.4.0->torch>=1.11.0->sentence-transformers>=3->sentence-transformers[train]>=3->setfit) (8.7.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers>=3->sentence-transformers[train]>=3->setfit) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from anyio->httpx<1.0.0->datasets) (1.3.1)
# Requirement already satisfied: zipp>=3.20 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from importlib-metadata->triton==3.4.0->torch>=1.11.0->sentence-transformers>=3->sentence-transformers[train]>=3->setfit) (3.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from jinja2->torch>=1.11.0->sentence-transformers>=3->sentence-transformers[train]>=3->setfit) (3.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from pandas->datasets) (2025.3)
# Requirement already satisfied: six>=1.5 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: joblib>=1.2.0 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from scikit-learn->setfit) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from scikit-learn->setfit) (3.6.0)
# Downloading setfit-1.1.3-py3-none-any.whl (75 kB)
# Downloading datasets-4.5.0-py3-none-any.whl (515 kB)
# Downloading dill-0.4.0-py3-none-any.whl (119 kB)
# Downloading multiprocess-0.70.18-py39-none-any.whl (133 kB)
# Downloading evaluate-0.4.6-py3-none-any.whl (84 kB)
# Downloading pyarrow-21.0.0-cp39-cp39-manylinux_2_28_x86_64.whl (42.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.7/42.7 MB 145.2 MB/s  0:00:00m0:00:01
# Downloading xxhash-3.6.0-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (192 kB)
# Installing collected packages: xxhash, pyarrow, dill, multiprocess, datasets, evaluate, setfit
#   Attempting uninstall: dill━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/7 [pyarrow]
#     Found existing installation: dill 0.4.1━━━━━━━━━━━━━━━━━━━ 1/7 [pyarrow]
#     Uninstalling dill-0.4.1:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/7 [pyarrow]
#       Successfully uninstalled dill-0.4.1━━━━━━━━━━━━━━━━━━━━━ 1/7 [pyarrow]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [setfit]2m6/7 [setfit]e]ess]
# Successfully installed datasets-4.5.0 dill-0.4.0 evaluate-0.4.6 multiprocess-0.70.18 pyarrow-21.0.0 setfit-1.1.3 xxhash-3.6.0
#
# [notice] A new release of pip is available: 20.0.2 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
from datasets import Dataset
from transformers import (
    AutoTokenizer,
    AutoModelForSequenceClassification,
    TrainingArguments,
    Trainer
)
from sklearn.metrics import accuracy_score, f1_score, precision_recall_fscore_support
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns

# %%
train_df = pd.read_csv('train_stance.csv', index_col=0)
test_df = pd.read_csv('test_stance.csv', index_col=0)

# %%
train_df
# Out:
#                                                    text  claim_labels  \
# 0     Of course, we have to improve the system, but ...           230
# 1     I think this is partly what's been going wrong...           230
# 2     No. I want to be a member of the European Unio...          1910
# 3     Well it depends whether you're talking about t...           107
# 4     But you are right when you say that you can't ...           230
# ...                                                 ...           ...
# 4117  Terry, like so many people around the country,...           107
# 4118  Terry, like so many people around the country,...           325
# 4119  Yeah, I was incredibly sad to have caused peop...          1609
# 4120  There are lots of people who go for private he...           108
# 4121  There are lots of people who go for private he...          1302
#
#        stance  confidence                                        topic_title
# 0     against    0.853987                                        Immigration
# 1     against    0.661541                                        Immigration
# 2     support    0.827143               Western Europe, Common Market Issues
# 3     neutral    0.590986               Taxation, Tax policy, and Tax Reform
# 4     against    0.695967                                        Immigration
# ...       ...         ...                                                ...
# 4117  support    0.615345               Taxation, Tax policy, and Tax Reform
# 4118  support    0.860713                       Health Manpower and Training
# 4119  support    0.951787                                    Veterans Issues
# 4120  support    0.614357  Industrial Policy, Privatisation, Nationalisation
# 4121  support    0.733669     Poverty and Assistance for Low-Income Families
#
# [3337 rows x 5 columns]

# %%
test_df
# Out:
#        ID                                               text  claim_labels  \
# 0       0  So knife crime's going to go up, because the e...          1211
# 1       1  Of course Gordon Brown's right to say there's ...           107
# 2       1  Of course Gordon Brown's right to say there's ...          1302
# 3       1  Of course Gordon Brown's right to say there's ...           602
# 4       1  Of course Gordon Brown's right to say there's ...           603
# ..    ...                                                ...           ...
# 534  2601  Well, I share the frustration of both our ques...           202
# 535  2601  Well, I share the frustration of both our ques...           230
# 536  3070  You're saying people voted for 10% tariffs on ...          1006
# 537  3356  I think this question of enthusiasm is really ...          2032
# 538  3356  I think this question of enthusiasm is really ...          1208
#
#       stance                                        topic_title
# 0    support                         Riots and Crime Prevention
# 1    against               Taxation, Tax policy, and Tax Reform
# 2    support     Poverty and Assistance for Low-Income Families
# 3    support                 Elementary and Secondary Education
# 4    support              Education of Underprivileged Students
# ..       ...                                                ...
# 534  support       Gender and Sexual Orientation Discrimination
# 535  neutral                                        Immigration
# 536  support     Truck and Automobile Transportation and Safety
# 537  support  Prime Ministerial or Ministerial Scandals and ...
# 538  neutral                                      Family Issues
#
# [537 rows x 5 columns]

# %%
label_map = {"support": 0, "against": 1, "neutral": 2}
train_df["label"] = train_df["stance"].map(label_map)
test_df["label"] = test_df["stance"].map(label_map)

# %%
test_df
# Out:
#        ID                                               text  claim_labels  \
# 0       0  So knife crime's going to go up, because the e...          1211
# 1       1  Of course Gordon Brown's right to say there's ...           107
# 2       1  Of course Gordon Brown's right to say there's ...          1302
# 3       1  Of course Gordon Brown's right to say there's ...           602
# 4       1  Of course Gordon Brown's right to say there's ...           603
# ..    ...                                                ...           ...
# 534  2601  Well, I share the frustration of both our ques...           202
# 535  2601  Well, I share the frustration of both our ques...           230
# 536  3070  You're saying people voted for 10% tariffs on ...          1006
# 537  3356  I think this question of enthusiasm is really ...          2032
# 538  3356  I think this question of enthusiasm is really ...          1208
#
#       stance                                        topic_title  label
# 0    support                         Riots and Crime Prevention    0.0
# 1    against               Taxation, Tax policy, and Tax Reform    1.0
# 2    support     Poverty and Assistance for Low-Income Families    0.0
# 3    support                 Elementary and Secondary Education    0.0
# 4    support              Education of Underprivileged Students    0.0
# ..       ...                                                ...    ...
# 534  support       Gender and Sexual Orientation Discrimination    0.0
# 535  neutral                                        Immigration    2.0
# 536  support     Truck and Automobile Transportation and Safety    0.0
# 537  support  Prime Ministerial or Ministerial Scandals and ...    0.0
# 538  neutral                                      Family Issues    2.0
#
# [537 rows x 6 columns]

# %%
for index, row in test_df.iterrows():
    if row['label'] not in [1.0, 2.0, 0.0]:
        print(f"{row['stance']}---{row['label']}")
# Out:
# against                         ---nan
# against  ---nan
# against ---nan
# against ---nan
# against ---nan
# against ---nan
# against ---nan
# against ---nan
# against ---nan
# against ---nan
# support ---nan
# support ---nan
# support ---nan
# against ---nan
# support ---nan
# against ---nan
# support ---nan
# against ---nan
# against ---nan
# against ---nan
# against ---nan
# against ---nan
# against ---nan
# against ---nan
# against ---nan
# support ---nan
# support ---nan
# support ---nan
# against ---nan
# support ---nan
# against ---nan
# against ---nan
# against ---nan
# support ---nan
# support ---nan
# support ---nan
# against ---nan
# support ---nan
# support ---nan
# against  ---nan

# %%
for index, row in test_df.iterrows():
    if row['stance'] not in ['support', 'against', 'neutral']:
        print(row['stance'])
# Out:
# against
# against
# against
# against
# against
# against
# against
# against
# against
# against
# support
# support
# support
# against
# support
# against
# support
# against
# against
# against
# against
# against
# against
# against
# against
# support
# support
# support
# against
# support
# against
# against
# against
# support
# support
# support
# against
# support
# support
# against

# %%
def fix_stances(stance):
    if 'support' in stance:
        return 'support'
    elif 'against' in stance:
        return 'against'
    elif 'neutral' in stance:
        return 'neutral'

# %%
test_df['stance'] = test_df['stance'].apply(fix_stances)

# %%
for index, row in test_df.iterrows():
    if row['stance'] not in ['support', 'against', 'neutral']:
        print(row['stance'])

# %%
test_df["label"] = test_df["stance"].map(label_map)

# %%
for index, row in test_df.iterrows():
    if row['label'] not in [0, 1, 2]:
        print(f"{row['stance']}---{row['label']}")
        
for index, row in train_df.iterrows():
    if row['label'] not in [0, 1, 2]:
        print(f"{row['stance']}---{row['label']}")

# %%
train_df
# Out:
#                                                    text  claim_labels  \
# 0     Of course, we have to improve the system, but ...           230
# 1     I think this is partly what's been going wrong...           230
# 2     No. I want to be a member of the European Unio...          1910
# 3     Well it depends whether you're talking about t...           107
# 4     But you are right when you say that you can't ...           230
# ...                                                 ...           ...
# 4117  Terry, like so many people around the country,...           107
# 4118  Terry, like so many people around the country,...           325
# 4119  Yeah, I was incredibly sad to have caused peop...          1609
# 4120  There are lots of people who go for private he...           108
# 4121  There are lots of people who go for private he...          1302
#
#        stance  confidence                                        topic_title  \
# 0     against    0.853987                                        Immigration
# 1     against    0.661541                                        Immigration
# 2     support    0.827143               Western Europe, Common Market Issues
# 3     neutral    0.590986               Taxation, Tax policy, and Tax Reform
# 4     against    0.695967                                        Immigration
# ...       ...         ...                                                ...
# 4117  support    0.615345               Taxation, Tax policy, and Tax Reform
# 4118  support    0.860713                       Health Manpower and Training
# 4119  support    0.951787                                    Veterans Issues
# 4120  support    0.614357  Industrial Policy, Privatisation, Nationalisation
# 4121  support    0.733669     Poverty and Assistance for Low-Income Families
#
#       label
# 0         1
# 1         1
# 2         0
# 3         2
# 4         1
# ...     ...
# 4117      0
# 4118      0
# 4119      0
# 4120      0
# 4121      0
#
# [3337 rows x 6 columns]

# %%
test_df
# Out:
#        ID                                               text  claim_labels  \
# 0       0  So knife crime's going to go up, because the e...          1211
# 1       1  Of course Gordon Brown's right to say there's ...           107
# 2       1  Of course Gordon Brown's right to say there's ...          1302
# 3       1  Of course Gordon Brown's right to say there's ...           602
# 4       1  Of course Gordon Brown's right to say there's ...           603
# ..    ...                                                ...           ...
# 534  2601  Well, I share the frustration of both our ques...           202
# 535  2601  Well, I share the frustration of both our ques...           230
# 536  3070  You're saying people voted for 10% tariffs on ...          1006
# 537  3356  I think this question of enthusiasm is really ...          2032
# 538  3356  I think this question of enthusiasm is really ...          1208
#
#       stance                                        topic_title  label
# 0    support                         Riots and Crime Prevention      0
# 1    against               Taxation, Tax policy, and Tax Reform      1
# 2    support     Poverty and Assistance for Low-Income Families      0
# 3    support                 Elementary and Secondary Education      0
# 4    support              Education of Underprivileged Students      0
# ..       ...                                                ...    ...
# 534  support       Gender and Sexual Orientation Discrimination      0
# 535  neutral                                        Immigration      2
# 536  support     Truck and Automobile Transportation and Safety      0
# 537  support  Prime Ministerial or Ministerial Scandals and ...      0
# 538  neutral                                      Family Issues      2
#
# [537 rows x 6 columns]

# %%
train_dataset = Dataset.from_pandas(train_df)
test_dataset = Dataset.from_pandas(test_df)

# %%
model_name = "roberta-base"
tokenizer = AutoTokenizer.from_pretrained(model_name)

# %%
def preprocess(example):
    return tokenizer(
        example["text"],
        example["topic_title"],
        truncation=True,
        padding="max_length",
        max_length=256
    )

# %%
train_dataset = train_dataset.map(preprocess, batched=True)
test_dataset = test_dataset.map(preprocess, batched=True)
# Out:
# Map:   0%|          | 0/3337 [00:00<?, ? examples/s]
# Map:   0%|          | 0/537 [00:00<?, ? examples/s]

# %%
train_dataset
# Out:
# Dataset({
#     features: ['claim_labels', 'confidence', 'label', '__index_level_0__', 'input_ids', 'attention_mask'],
#     num_rows: 3337
# })

# %%
test_dataset
# Out:
# Dataset({
#     features: ['ID', 'text', 'claim_labels', 'stance', 'topic_title', 'label', '__index_level_0__', 'input_ids', 'attention_mask'],
#     num_rows: 537
# })

# %%
train_dataset = train_dataset.remove_columns(["text", "topic_title", "stance"])

# %%
train_dataset = train_dataset.remove_columns(["claim_labels", "confidence", "__index_level_0__"])

# %%
test_dataset = test_dataset.remove_columns(["ID", "claim_labels", "text", "__index_level_0__", "topic_title", "stance"])

# %%
test_dataset
# Out:
# Dataset({
#     features: ['label', 'input_ids', 'attention_mask'],
#     num_rows: 537
# })

# %%
train_dataset.set_format("torch")
test_dataset.set_format("torch")

# %%
model = AutoModelForSequenceClassification.from_pretrained(
    model_name,
    num_labels=3
)
# Out:
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at roberta-base and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
def compute_metrics(eval_pred):
    logits, labels = eval_pred
    preds = np.argmax(logits, axis=1)
    precision, recall, f1, _  = precision_recall_fscore_support(
            labels, preds, average="macro", zero_division=0)
    return {
        "accuracy": accuracy_score(labels, preds),
        "precision": precision,
        "recall": recall,
        "macro_f1": f1        
    }

# %%
training_args = TrainingArguments(
    output_dir="./stance_model",
    eval_strategy="epoch",
    save_strategy="epoch",
    logging_strategy="epoch",
    
    learning_rate=2e-5,
    per_device_train_batch_size=8,
    per_device_eval_batch_size=16,
    
    num_train_epochs=5,
    weight_decay=0.01,
    
    load_best_model_at_end=True,
    metric_for_best_model="macro_f1",
    greater_is_better=True,
    
    warmup_ratio=0.1,
    lr_scheduler_type="linear",
    
    fp16=True, 
    save_total_limit=2
)

# %%
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=test_dataset,
    processing_class=tokenizer,
    compute_metrics=compute_metrics
)
# Out:
# Detected kernel version 5.4.0, which is below the recommended minimum of 5.5.0; this can cause the process to hang. It is recommended to upgrade the kernel to the minimum version or higher.
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 trainer = Trainer(
#       2     model=model,
#       3     args=training_args,
#       4     train_dataset=train_dataset,
#       5     eval_dataset=test_dataset,
#       6     processing_class=tokenizer,
#       7     compute_metrics=compute_metrics
#       8 )
#
# File ~/joel_jupyterenv-3.9/lib/python3.9/site-packages/transformers/utils/deprecation.py:172, in deprecate_kwarg.<locals>.wrapper.<locals>.wrapped_func(*args, **kwargs)
#     168 elif minimum_action in (Action.NOTIFY, Action.NOTIFY_ALWAYS) and not is_torchdynamo_compiling():
#     169     # DeprecationWarning is ignored by default, so we use FutureWarning instead
#     170     warnings.warn(message, FutureWarning, stacklevel=2)
# --> 172 return func(*args, **kwargs)
#
# File ~/joel_jupyterenv-3.9/lib/python3.9/site-packages/transformers/trainer.py:612, in Trainer.__init__(self, model, args, data_collator, train_dataset, eval_dataset, processing_class, model_init, compute_loss_func, compute_metrics, callbacks, optimizers, optimizer_cls_and_kwargs, preprocess_logits_for_metrics)
#     607 # Bnb Quantized models doesn't support `.to` operation.
#     608 if (
#     609     self.place_model_on_device
#     610     and getattr(model, "quantization_method", None) != QuantizationMethod.BITS_AND_BYTES
#     611 ):
# --> 612     self._move_model_to_device(model, args.device)
#     614 # Force n_gpu to 1 to avoid DataParallel as MP will manage the GPUs
#     615 if self.is_model_parallel:
#
# File ~/joel_jupyterenv-3.9/lib/python3.9/site-packages/transformers/trainer.py:910, in Trainer._move_model_to_device(self, model, device)
#     906     logger.warning(
#     907         "The model is already on multiple devices. Skipping the move to device specified in `args`."
#     908     )
#     909     return
# --> 910 model = model.to(device)
#     911 # Moving a model to an XLA device disconnects the tied weights, so we have to retie them.
#     912 if self.args.parallel_mode == ParallelMode.TPU and hasattr(model, "tie_weights"):
#
# File ~/joel_jupyterenv-3.9/lib/python3.9/site-packages/transformers/modeling_utils.py:4343, in PreTrainedModel.to(self, *args, **kwargs)
#    4338     if dtype_present_in_args:
#    4339         raise ValueError(
#    4340             "You cannot cast a GPTQ model in a new `dtype`. Make sure to load the model using `from_pretrained` using the desired"
#    4341             " `dtype` by passing the correct `dtype` argument."
#    4342         )
# -> 4343 return super().to(*args, **kwargs)
#
# File ~/joel_jupyterenv-3.9/lib/python3.9/site-packages/torch/nn/modules/module.py:1369, in Module.to(self, *args, **kwargs)
#    1366         else:
#    1367             raise
# -> 1369 return self._apply(convert)
#
# File ~/joel_jupyterenv-3.9/lib/python3.9/site-packages/torch/nn/modules/module.py:928, in Module._apply(self, fn, recurse)
#     926 if recurse:
#     927     for module in self.children():
# --> 928         module._apply(fn)
#     930 def compute_should_use_set_data(tensor, tensor_applied):
#     931     if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     932         # If the new tensor has compatible tensor type as the existing tensor,
#     933         # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     938         # global flag to let the user control whether they want the future
#     939         # behavior of overwriting the existing tensor or not.
#
# File ~/joel_jupyterenv-3.9/lib/python3.9/site-packages/torch/nn/modules/module.py:928, in Module._apply(self, fn, recurse)
#     926 if recurse:
#     927     for module in self.children():
# --> 928         module._apply(fn)
#     930 def compute_should_use_set_data(tensor, tensor_applied):
#     931     if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     932         # If the new tensor has compatible tensor type as the existing tensor,
#     933         # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     938         # global flag to let the user control whether they want the future
#     939         # behavior of overwriting the existing tensor or not.
#
#     [... skipping similar frames: Module._apply at line 928 (4 times)]
#
# File ~/joel_jupyterenv-3.9/lib/python3.9/site-packages/torch/nn/modules/module.py:928, in Module._apply(self, fn, recurse)
#     926 if recurse:
#     927     for module in self.children():
# --> 928         module._apply(fn)
#     930 def compute_should_use_set_data(tensor, tensor_applied):
#     931     if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     932         # If the new tensor has compatible tensor type as the existing tensor,
#     933         # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     938         # global flag to let the user control whether they want the future
#     939         # behavior of overwriting the existing tensor or not.
#
# File ~/joel_jupyterenv-3.9/lib/python3.9/site-packages/torch/nn/modules/module.py:955, in Module._apply(self, fn, recurse)
#     951 # Tensors stored in modules are graph leaves, and we don't want to
#     952 # track autograd history of `param_applied`, so we have to use
#     953 # `with torch.no_grad():`
#     954 with torch.no_grad():
# --> 955     param_applied = fn(param)
#     956 p_should_use_set_data = compute_should_use_set_data(param, param_applied)
#     958 from torch._subclasses.fake_tensor import FakeTensor
#
# File ~/joel_jupyterenv-3.9/lib/python3.9/site-packages/torch/nn/modules/module.py:1355, in Module.to.<locals>.convert(t)
#    1348     if convert_to_format is not None and t.dim() in (4, 5):
#    1349         return t.to(
#    1350             device,
#    1351             dtype if t.is_floating_point() or t.is_complex() else None,
#    1352             non_blocking,
#    1353             memory_format=convert_to_format,
#    1354         )
# -> 1355     return t.to(
#    1356         device,
#    1357         dtype if t.is_floating_point() or t.is_complex() else None,
#    1358         non_blocking,
#    1359     )
#    1360 except NotImplementedError as e:
#    1361     if str(e) == "Cannot copy out of meta tensor; no data!":
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 20.00 MiB. GPU 0 has a total capacity of 9.50 GiB of which 4.94 MiB is free. Process 3092182 has 226.00 MiB memory in use. Process 3157315 has 9.13 GiB memory in use. Process 3167073 has 274.00 MiB memory in use. Process 3169044 has 138.00 MiB memory in use. Process 3177972 has 740.00 MiB memory in use. Process 3207973 has 638.00 MiB memory in use. Process 3211597 has 156.00 MiB memory in use. Including non-PyTorch memory, this process has 344.00 MiB memory in use. Of the allocated memory 258.17 MiB is allocated by PyTorch, and 11.83 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

# %%
trainer.train()
# Out:
#     <div>
#
#       <progress value='2090' max='2090' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2090/2090 04:50, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>Macro F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.436800</td>
#       <td>0.969489</td>
#       <td>0.703911</td>
#       <td>0.769461</td>
#       <td>0.551795</td>
#       <td>0.589312</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.416900</td>
#       <td>0.924542</td>
#       <td>0.694600</td>
#       <td>0.702128</td>
#       <td>0.559108</td>
#       <td>0.597804</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.328600</td>
#       <td>1.365776</td>
#       <td>0.687151</td>
#       <td>0.742280</td>
#       <td>0.576624</td>
#       <td>0.611453</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.245600</td>
#       <td>1.597856</td>
#       <td>0.677840</td>
#       <td>0.681046</td>
#       <td>0.558978</td>
#       <td>0.593297</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.166200</td>
#       <td>1.798108</td>
#       <td>0.677840</td>
#       <td>0.703883</td>
#       <td>0.560543</td>
#       <td>0.592686</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=2090, training_loss=0.3188158573716451, metrics={'train_runtime': 290.3513, 'train_samples_per_second': 57.465, 'train_steps_per_second': 7.198, 'total_flos': 2195023687395840.0, 'train_loss': 0.3188158573716451, 'epoch': 5.0})

# %%
results = trainer.evaluate()
print(results)
# Out:
#     <div>
#
#       <progress value='34' max='34' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [34/34 00:01]
#     </div>
# {'eval_loss': 1.3657760620117188, 'eval_accuracy': 0.6871508379888268, 'eval_precision': 0.7422803835602738, 'eval_recall': 0.5766243213051724, 'eval_macro_f1': 0.6114531793866181, 'eval_runtime': 2.0491, 'eval_samples_per_second': 262.065, 'eval_steps_per_second': 16.593, 'epoch': 5.0}

# %%
def plot_loss_curves(train_losses, eval_losses, name):    
    sns.set_style("whitegrid")
    
    plt.figure(figsize=(8, 5))
    
    plt.plot(train_losses, label='Train Loss', color='#2ecc71', marker='o') # Green
    plt.plot(eval_losses, label='Eval Loss', color='#e74c3c', marker='o')  # Red
    
    plt.gca().xaxis.set_major_locator(ticker.MaxNLocator(integer=True))
    
    plt.title('Training vs Evaluation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    
    plt.savefig(f"{name}_loss_plot.png")
    plt.show()

# %%
#For loss:
history = trainer.state.log_history
train_loss = [log['loss'] for log in history if 'loss' in log]
eval_loss = [log['eval_loss'] for log in history if 'eval_loss' in log]

# %%
plot_loss_curves(train_loss, eval_loss, model_name)

# %%
def hp_space(trial):
    return {
        "learning_rate": trial.suggest_float("learning_rate", 1e-5, 5e-5, log=True),
        "num_train_epochs": trial.suggest_int("num_train_epochs", 3, 6),
        "per_device_train_batch_size": trial.suggest_categorical(
            "per_device_train_batch_size", [8, 16]
        ),
        "weight_decay": trial.suggest_float("weight_decay", 0.0, 0.1),
        "warmup_ratio": trial.suggest_float("warmup_ratio", 0.0, 0.2),
    }

# %%
def model_init():
    return AutoModelForSequenceClassification.from_pretrained(
        model_name,
        num_labels=3
    )

# %%
trainer = Trainer(
    model_init=model_init,  
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=test_dataset,
    tokenizer=tokenizer,
    compute_metrics=compute_metrics
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 trainer = Trainer(
#       2     model_init=model_init,
#       3     args=training_args,
#       4     train_dataset=train_dataset,
#       5     eval_dataset=test_dataset,
#       6     tokenizer=tokenizer,
#       7     compute_metrics=compute_metrics
#       8 )
#
# NameError: name 'Trainer' is not defined
