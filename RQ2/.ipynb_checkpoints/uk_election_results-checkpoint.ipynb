# %% [markdown]
# ### Package Installation

# %%
! pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from seaborn) (2.0.2)
# Requirement already satisfied: pandas>=1.2 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from seaborn) (3.9.4)
# Requirement already satisfied: contourpy>=1.0.1 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.60.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (6.5.2)
# Requirement already satisfied: zipp>=3.1.0 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.4->seaborn) (3.23.0)
# Requirement already satisfied: pytz>=2020.1 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from pandas>=1.2->seaborn) (2025.3)
# Requirement already satisfied: six>=1.5 in /home2/pwfb75/joel_jupyterenv-3.9/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
#
# [notice] A new release of pip is available: 20.0.2 -> 26.0
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_theme(style="whitegrid")

# %% [markdown]
# ### Election Data

# %% [markdown]
# Election Years:
# * 2005, 2010, 2015, 2017, 2019, 2024
#
# Parties:
# * 2005
#     * Conservatives, Labour, Lib Dem
# * 2010
#     * Cons, Lab, LibD
# * 2015
#     * Cons, Lab, LibD, Green,  UKIP, Plaid, SNP
# * 2017
#     * Cons, Lab, Libd, Green, Plaid, SNP, UKIP
# * 2019
#     * Cons, Lab, SNP, Libd, Green, Plaid, Brexit
# * 2024
#     * Cons, Lab, Libd, SNP, Reform, Green, Plaid

# %%
# working class election results
election_results = {
    'election':   [2024, 2019, 2017, 2015, 2010, 2005, 
                   2024, 2019, 2017, 2015, 2010, 2005, 
                   2024, 2019, 2017, 2015, 2010, 2005, 
                   2024, 2019, 2017, 2015,
                   2024,
                   2024, 2019, 2017, 2015,
                   2024, 2019, 2017, 2015,
                   2019,
                   2017, 2015],
    
    'party': ['Conservatives', 'Conservatives', 'Conservatives', 'Conservatives', 'Conservatives', 'Conservatives',
              'Labour', 'Labour', 'Labour', 'Labour', 'Labour', 'Labour', 
              'Liberal Democrats', 'Liberal Democrats', 'Liberal Democrats', 'Liberal Democrats', 'Liberal Democrats', 'Liberal Democrats', 
              'SNP', 'SNP', 'SNP', 'SNP', 
              'Reform UK',
              'Green', 'Green', 'Green', 'Green', 
              'Plaid Cymru', 'Plaid Cymru', 'Plaid Cymru', 'Plaid Cymru', 
              'Brexit',
              'UKIP', 'UKIP'
              ],

    'c2_vote': [0.24,0.49,0.47,0.36,0.37,0.33, #Cons
                0.32,0.31,0.40,0.31,0.29,0.40, #Lab
                0.11,0.09,0.06,0.06,0.22,0.19, #Lib
                0.03,0.04,0.03,0.05,     #SNP
                0.20,                 #Reform
                0.06,0.03,0.01,0.03,     #Green
                0.01,0.00,0.00,0.01,      #Plaid
                0.03,                 #Brexit
                0.02,0.17                   #UKIP
               ],
    
    'de_vote': [0.23,0.47,0.41,0.29,0.31,0.25,    #Cons
                0.34,0.34,0.44,0.37,0.40,0.48,    #Lab
                0.10,0.08,0.05,0.06,0.17,0.18,    #Lib
                0.03,0.04,0.04,0.05,        #SNP
                0.19,                 #Reform 
                0.06,0.02,0.02,0.03,        #Green
                0.01,0.00,0.00,0.00,        #Plaid
                0.03,                 #Brexit
                0.04,0.18                   #UKIP
               ],
    
    'c2de_vote': [0.23,0.48,0.44,0.33,0.34,0,  #Cons
                  0.33,0.33,0.42,0.34,0.35,0,  #Lab
                  0.11,0.08,0.06,0.06,0.20,0,  #Lib
                  0.03,0.04,0.04,0.05,      #SNP
                  0.20,               #Reform 
                  0.06,0.02,0.01,0.03,      #Green
                  0.01,0.00,0.00,0.01,      #Plaid
                  0.03,               #Brexit
                  0.03,0.18                 #UKIP
                 ]

}

# %%
len(election_results['c2de_vote'])
# Out:
# 34

# %% [markdown]
# Sources:
# * 2024: https://www.ipsos.com/en-uk/uk-opinion-polls/how-britain-voted-in-the-2024-election
# * 2024: https://yougov.co.uk/politics/articles/49978-how-britain-voted-in-the-2024-general-election
# * 2019, 2017, 2015 are from YouGov
# * 2010 and 2005 are from IPSOS

# %% [markdown]
# The IPSOS data groups SNP and Plaid together on 4% in 2024. For the purpose of analysis this is split equally: 2% each

# %%
df = pd.DataFrame(election_results)
df
# Out:
#     election              party  c2_vote  de_vote  c2de_vote
# 0       2024      Conservatives     0.24     0.23       0.23
# 1       2019      Conservatives     0.49     0.47       0.48
# 2       2017      Conservatives     0.47     0.41       0.44
# 3       2015      Conservatives     0.36     0.29       0.33
# 4       2010      Conservatives     0.37     0.31       0.34
# 5       2005      Conservatives     0.33     0.25       0.00
# 6       2024             Labour     0.32     0.34       0.33
# 7       2019             Labour     0.31     0.34       0.33
# 8       2017             Labour     0.40     0.44       0.42
# 9       2015             Labour     0.31     0.37       0.34
# 10      2010             Labour     0.29     0.40       0.35
# 11      2005             Labour     0.40     0.48       0.00
# 12      2024  Liberal Democrats     0.11     0.10       0.11
# 13      2019  Liberal Democrats     0.09     0.08       0.08
# 14      2017  Liberal Democrats     0.06     0.05       0.06
# 15      2015  Liberal Democrats     0.06     0.06       0.06
# 16      2010  Liberal Democrats     0.22     0.17       0.20
# 17      2005  Liberal Democrats     0.19     0.18       0.00
# 18      2024                SNP     0.03     0.03       0.03
# 19      2019                SNP     0.04     0.04       0.04
# 20      2017                SNP     0.03     0.04       0.04
# 21      2015                SNP     0.05     0.05       0.05
# 22      2024          Reform UK     0.20     0.19       0.20
# 23      2024              Green     0.06     0.06       0.06
# 24      2019              Green     0.03     0.02       0.02
# 25      2017              Green     0.01     0.02       0.01
# 26      2015              Green     0.03     0.03       0.03
# 27      2024        Plaid Cymru     0.01     0.01       0.01
# 28      2019        Plaid Cymru     0.00     0.00       0.00
# 29      2017        Plaid Cymru     0.00     0.00       0.00
# 30      2015        Plaid Cymru     0.01     0.00       0.01
# 31      2019             Brexit     0.03     0.03       0.03
# 32      2017               UKIP     0.02     0.04       0.03
# 33      2015               UKIP     0.17     0.18       0.18

# %%
sns.lineplot(data=df, x='election', y='c2de_vote', hue='party', marker='o')
years = sorted(df['election'].unique())
plt.xticks(years)
plt.legend(
    title='Political Parties',   
    bbox_to_anchor=(1.05, 1),    
    loc='upper left',            
    borderaxespad=0.             
)
plt.title('Working Class Voter Share Over Time (C2DE Demographic)')
plt.ylabel('Vote Share (%)')
plt.xlabel('Election Year')
plt.show()

# %%
df_2024 = df[df['election'] == 2024]
df_melted = df_2024.melt(id_vars='party', value_vars=['c2_vote', 'de_vote'], 
                         var_name='Demographic', value_name='Vote Share (%)')
plt.figure(figsize=(8, 5))
sns.barplot(data=df_melted, x='party', y='Vote Share (%)', hue='Demographic')
plt.title('Party Comparison: C2 vs DE Vote Share (2024)')
plt.xlabel("Party")
plt.xticks(rotation=90)
plt.show()
